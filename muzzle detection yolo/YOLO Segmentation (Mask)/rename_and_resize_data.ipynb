# %% [markdown]
# ## Cattle Muzzle Data Preprocessing Notebook
#
# This notebook processes raw cattle muzzle images from the `data` folder:
# - Renames files to standardized `muzzle_XXXXX.jpg` format
# - Converts images to RGB JPEG format
# - Compresses with quality 80% to reduce file size
# - Saves processed images to `processed_data` folder
#
# Supports multiple input formats: .jpg, .jpeg, .png, .bmp, .webp

# %%
import os
from PIL import Image

# %% [markdown]
# ### Select sizes

# %%
input_folder = "data"
output_folder = "processed_data"
# new_width = 640   # change width as needed
# new_height = 640  # change height as needed
image_quality = 80  # reduce file size (1-95)

# %%
# Create output folder if not exists
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# %% [markdown]
# ## Process

# %%
image_extensions = (".jpg", ".jpeg", ".png", ".bmp", ".webp")
files = [f for f in os.listdir(input_folder) if f.lower().endswith(image_extensions)]

files.sort()

counter = 1

for file in files:
    input_path = os.path.join(input_folder, file)

    try:
        img = Image.open(input_path)

        # Convert to RGB (important for PNG, WEBP etc.)
        if img.mode != "RGB":
            img = img.convert("RGB")

        # New filename
        new_name = f"muzzle_{counter:05d}.jpg"
        output_path = os.path.join(output_folder, new_name)

        # Save with compression (no resizing)
        img.save(output_path, "JPEG", quality=image_quality, optimize=True)

        print(f"Processed: {new_name}")
        counter += 1

    except Exception as e:
        print(f"Error processing {file}: {e}")

print("Done")
# Out:
# Processed: muzzle_00001.jpg
# Processed: muzzle_00002.jpg
# Processed: muzzle_00003.jpg
# Processed: muzzle_00004.jpg
# Processed: muzzle_00005.jpg
# Processed: muzzle_00006.jpg
# Processed: muzzle_00007.jpg
# Processed: muzzle_00008.jpg
# Processed: muzzle_00009.jpg
# Processed: muzzle_00010.jpg
# Processed: muzzle_00011.jpg
# Processed: muzzle_00012.jpg
# Processed: muzzle_00013.jpg
# Processed: muzzle_00014.jpg
# Processed: muzzle_00015.jpg
# Processed: muzzle_00016.jpg
# Processed: muzzle_00017.jpg
# Processed: muzzle_00018.jpg
# Processed: muzzle_00019.jpg
# Processed: muzzle_00020.jpg
# Processed: muzzle_00021.jpg
# Processed: muzzle_00022.jpg
# Processed: muzzle_00023.jpg
# Processed: muzzle_00024.jpg
# Processed: muzzle_00025.jpg
# Processed: muzzle_00026.jpg
# Processed: muzzle_00027.jpg
# Processed: muzzle_00028.jpg
# Processed: muzzle_00029.jpg
# Processed: muzzle_00030.jpg
# Processed: muzzle_00031.jpg
# Processed: muzzle_00032.jpg
# Processed: muzzle_00033.jpg
# Processed: muzzle_00034.jpg
# Processed: muzzle_00035.jpg
# Processed: muzzle_00036.jpg
# Processed: muzzle_00037.jpg
# Processed: muzzle_00038.jpg
# Processed: muzzle_00039.jpg
# Processed: muzzle_00040.jpg
# Processed: muzzle_00041.jpg
# Processed: muzzle_00042.jpg
# Processed: muzzle_00043.jpg
# Processed: muzzle_00044.jpg
# Processed: muzzle_00045.jpg
# Processed: muzzle_00046.jpg
# Processed: muzzle_00047.jpg
# Processed: muzzle_00048.jpg
# Processed: muzzle_00049.jpg
# Processed: muzzle_00050.jpg
# Processed: muzzle_00051.jpg
# Processed: muzzle_00052.jpg
# Processed: muzzle_00053.jpg
# Processed: muzzle_00054.jpg
# Processed: muzzle_00055.jpg
# Processed: muzzle_00056.jpg
# Processed: muzzle_00057.jpg
# Processed: muzzle_00058.jpg
# Processed: muzzle_00059.jpg
# Processed: muzzle_00060.jpg
# Processed: muzzle_00061.jpg
# Processed: muzzle_00062.jpg
# Processed: muzzle_00063.jpg
# Processed: muzzle_00064.jpg
# Processed: muzzle_00065.jpg
# Processed: muzzle_00066.jpg
# Processed: muzzle_00067.jpg
# Processed: muzzle_00068.jpg
# Processed: muzzle_00069.jpg
# Processed: muzzle_00070.jpg
# Processed: muzzle_00071.jpg
# Processed: muzzle_00072.jpg
# Processed: muzzle_00073.jpg
# Processed: muzzle_00074.jpg
# Processed: muzzle_00075.jpg
# Processed: muzzle_00076.jpg
# Processed: muzzle_00077.jpg
# Processed: muzzle_00078.jpg
# Processed: muzzle_00079.jpg
# Processed: muzzle_00080.jpg
# Processed: muzzle_00081.jpg
# Processed: muzzle_00082.jpg
# Processed: muzzle_00083.jpg
# Processed: muzzle_00084.jpg
# Processed: muzzle_00085.jpg
# Processed: muzzle_00086.jpg
# Processed: muzzle_00087.jpg
# Processed: muzzle_00088.jpg
# Processed: muzzle_00089.jpg
# Processed: muzzle_00090.jpg
# Processed: muzzle_00091.jpg
# Processed: muzzle_00092.jpg
# Processed: muzzle_00093.jpg
# Processed: muzzle_00094.jpg
# Processed: muzzle_00095.jpg
# Processed: muzzle_00096.jpg
# Processed: muzzle_00097.jpg
# Processed: muzzle_00098.jpg
# Processed: muzzle_00099.jpg
# Processed: muzzle_00100.jpg
# Done
